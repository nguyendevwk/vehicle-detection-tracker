# %%
# !nvidia-smi
# Out:
# Wed Mar 12 03:35:31 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 932.9/932.9 kB 21.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 63.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.88 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.2/107.7 GB disk)

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolo11n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# ...
# 100% 5.35M/5.35M [00:00<00:00, 98.6MB/s]
# Ultralytics 8.3.88 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 39.1MB/s]
# image 1/1 /content/dog.jpeg: 640x384 2 persons, 1 car, 1 dog, 1 handbag, 150.6ms
# Speed: 14.9ms preprocess, 150.6ms inference, 30.2ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='/content/runs/detect/predict/dog.jpg', height=600)
# Out:
# /content

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolo11n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# Ultralytics 8.3.88 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /content/dog.jpeg: 640x384 2 persons, 1 car, 1 dog, 1 handbag, 155.9ms
# Speed: 4.2ms preprocess, 155.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
model = YOLO(f'/content/yolo11n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /content/dog.jpeg: 640x384 2 persons, 1 car, 1 dog, 1 handbag, 156.8ms
# Speed: 6.3ms preprocess, 156.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)

# %%
results[0].boxes.xyxy
# Out:
# tensor([[3.0705e+02, 6.4341e+02, 5.2919e+02, 1.2558e+03],
#         [6.1400e+01, 2.4994e+02, 6.5165e+02, 9.7412e+02],
#         [1.7803e+00, 3.5551e+02, 6.3404e+02, 1.2788e+03],
#         [1.1933e+00, 3.5620e+02, 3.8455e+02, 1.2776e+03],
#         [6.2615e+02, 7.1818e+02, 6.9975e+02, 7.8754e+02]])

# %%
results[0].boxes.conf
# Out:
# tensor([0.6832, 0.6284, 0.5941, 0.3923, 0.3875])

# %%
results[0].boxes.cls
# Out:
# tensor([26., 16.,  0.,  0.,  2.])

# %%
# !cp -r "/content/DATA-ANALYTICS-3-(BACKUP)-1/valid" "/content/Street-View-3/"

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet

# from roboflow import Roboflow
# rf = Roboflow(api_key="lFkNpRy376TKRm7kizku")
# project = rf.workspace("fsmvu").project("street-view-gdogo")
# dataset = project.version(1).download("yolov8")


# !pip install roboflow --quiet

# from roboflow import Roboflow
# rf = Roboflow(api_key="lFkNpRy376TKRm7kizku")
# project = rf.workspace("fsmvu").project("street-view-gdogo")
# dataset = project.version(3).download("yolo11")

# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="lFkNpRy376TKRm7kizku")
# project = rf.workspace("test-bihil").project("data-analytics-3-backup-mnmkp")
# version = project.version(1)
# dataset = version.download("yolov11")

# !pip install roboflow --quiet
# !pip install roboflow
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="lFkNpRy376TKRm7kizku")
# project = rf.workspace("test-bihil").project("vehicles-q0x2v-kz281")
# version = project.version(1)
# dataset = version.download("yolov11")
# Out:
# mkdir: cannot create directory ‘{HOME}/datasets’: No such file or directory
# [Errno 2] No such file or directory: '{HOME}/datasets'
# /content
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to DATA-ANALYTICS-3-(BACKUP)-1 in yolov11:: 100%|██████████| 8070/8070 [00:06<00:00, 1261.08it/s]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
import os
import random
from matplotlib import pyplot as plt
from PIL import Image

image_directory = f'{HOME}/Street-View-3/train/images'

image_files = os.listdir(image_directory)

random_images = random.sample(image_files, 5)

# Hiển thị hình ảnh ngẫu nhiên
plt.figure(figsize=(20, 5))
for i, image_name in enumerate(random_images):
    image_path = os.path.join(image_directory, image_name)
    img = Image.open(image_path)

    plt.subplot(1, 5, i+1)
    plt.imshow(img)
    plt.title(f'Image {i+1}')
    plt.axis('off')

plt.show()

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolo11n.pt data='/content/Street-View-3/data.yaml' epochs=25 imgsz=640 plots=True
# Out:
# /content
# Ultralytics 8.3.88 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !ls {HOME}/runs/detect/train/

# %%
from IPython.display import display, Image

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=800)

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=1000)

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/F1_curve.png', width=800)

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/PR_curve.png', width=800)

# %%
Image(filename=f'{HOME}/runs/detect/train/P_curve.png', width=800)

# %%
Image(filename=f'{HOME}/runs/detect/train/R_curve.png', width=800)

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=2000)

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict3/*.jpg')[:10]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
#Run inference on your model on a persistant, auto-scaling, cloud API

#load model
model = project.version(dataset.version).model

#choose random test set image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred

# %%
import ultralytics
print(ultralytics.__version__)
